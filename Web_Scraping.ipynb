# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakharava/ML-Data-Science/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
web = requests.get("https://nanonets.com/website-scraper")
print(web)
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><!-- Last Published: Sun Jul 07 2024 12:49:41 GMT+0000 (Coordinated Universal Time) --><html data-wf-domain="case-study-page-nanonets.webflow.io" data-wf-page="635b11d9fcbc701f8059335b" data-wf-site="602f5458a0b1d868c6c84d5b" lang="en"><head><meta charset="utf-8"/><title>Free Web Scraping Tool - Nanonets Online Web Scraper</title><link rel="alternate" hrefLang="x-default" href="https://case-study-page-nanonets.webflow.io/website-scraper"/><link rel="alternate" hrefLang="en" href="https://case-study-page-nanonets.webflow.io/website-scraper"/><link rel="alternate" hrefLang="fr" href="https://case-study-page-nanonets.webflow.io/fr/website-scraper"/><meta content="Free web scraping tool to convert HTML to text. Use Nanonets&#x27; web scraper with Python API integration to instantly convert any website URL to a txt file." name="description"/><meta content="Free Web Scraping Tool - Nanonets Online Web Scraper" property="og:title"/><meta content="Free web scraping tool to c
# ...

# %%
web.url
# Out:
# 'https://nanonets.com/website-scraper'

# %%
web.status_code
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get("https://nanonets.com/website-scraper")

# %%
web.status_code
# Out:
# 200

# %%
web.content
# Out:
# b'<!DOCTYPE html><!-- Last Published: Sun Jul 07 2024 12:49:41 GMT+0000 (Coordinated Universal Time) --><html data-wf-domain="case-study-page-nanonets.webflow.io" data-wf-page="635b11d9fcbc701f8059335b" data-wf-site="602f5458a0b1d868c6c84d5b" lang="en"><head><meta charset="utf-8"/><title>Free Web Scraping Tool - Nanonets Online Web Scraper</title><link rel="alternate" hrefLang="x-default" href="https://case-study-page-nanonets.webflow.io/website-scraper"/><link rel="alternate" hrefLang="en" href="https://case-study-page-nanonets.webflow.io/website-scraper"/><link rel="alternate" hrefLang="fr" href="https://case-study-page-nanonets.webflow.io/fr/website-scraper"/><meta content="Free web scraping tool to convert HTML to text. Use Nanonets&#x27; web scraper with Python API integration to instantly convert any website URL to a txt file." name="description"/><meta content="Free Web Scraping Tool - Nanonets Online Web Scraper" property="og:title"/><meta content="Free web scraping tool to c
# ...

# %%
soup = BeautifulSoup(web.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- Last Published: Sun Jul 07 2024 12:49:41 GMT+0000 (Coordinated Universal Time) -->
# <html data-wf-domain="case-study-page-nanonets.webflow.io" data-wf-page="635b11d9fcbc701f8059335b" data-wf-site="602f5458a0b1d868c6c84d5b" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Free Web Scraping Tool - Nanonets Online Web Scraper
#   </title>
#   <link href="https://case-study-page-nanonets.webflow.io/website-scraper" hreflang="x-default" rel="alternate"/>
#   <link href="https://case-study-page-nanonets.webflow.io/website-scraper" hreflang="en" rel="alternate"/>
#   <link href="https://case-study-page-nanonets.webflow.io/fr/website-scraper" hreflang="fr" rel="alternate"/>
#   <meta content="Free web scraping tool to convert HTML to text. Use Nanonets' web scraper with Python API integration to instantly convert any website URL to a txt file." name="description"/>
# ...

# %%
soup.title
# Out:
# <title>Free Web Scraping Tool - Nanonets Online Web Scraper</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p
# Out:
# <p class="paragraph-34">Data security comes first – We'll never sell or share your data. For more details, here’s our <a class="link-6" href="https://legal.nanonets.com/privacy" target="_blank">Privacy Policy</a></p>

# %%
soup.a
# Out:
# <a class="nav__logo w-nav-brand" href="https://nanonets.com/"><img alt="nanonets logo" class="image-127" height="30" loading="lazy" src="https://cdn.prod.website-files.com/602f5458a0b1d868c6c84d5b/60307e489ca8621554af197d_logo2.webp" width="123"/></a>

# %%
soup.h1
# Out:
# <h1 class="heading-34">Free Web Scraping Tool - Convert Website to Text</h1>

# %% [markdown]
# # **TAG**

# %%
tag = soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.p
tag
# Out:
# <p class="paragraph-34">Data security comes first – We'll never sell or share your data. For more details, here’s our <a class="link-6" href="https://legal.nanonets.com/privacy" target="_blank">Privacy Policy</a></p>

# %%
tag = soup.a
tag
# Out:
# <a class="nav__logo w-nav-brand" href="https://nanonets.com/"><img alt="nanonets logo" class="image-127" height="30" loading="lazy" src="https://cdn.prod.website-files.com/602f5458a0b1d868c6c84d5b/60307e489ca8621554af197d_logo2.webp" width="123"/></a>

# %% [markdown]
# # **NAVIGABLE** **STRING**

# %%
tag = soup.p.string
tag

# %%
tag = soup.a.string
tag

# %%
tag = soup.h1.string
tag
# Out:
# 'Free Web Scraping Tool - Convert Website to Text'

# %% [markdown]
# # **BEAUTIFULSOUP**

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>Free Web Scraping Tool - Nanonets Online Web Scraper</title>

# %%
soup.head
# Out:
# <head><meta charset="utf-8"/><title>Free Web Scraping Tool - Nanonets Online Web Scraper</title><link href="https://case-study-page-nanonets.webflow.io/website-scraper" hreflang="x-default" rel="alternate"/><link href="https://case-study-page-nanonets.webflow.io/website-scraper" hreflang="en" rel="alternate"/><link href="https://case-study-page-nanonets.webflow.io/fr/website-scraper" hreflang="fr" rel="alternate"/><meta content="Free web scraping tool to convert HTML to text. Use Nanonets' web scraper with Python API integration to instantly convert any website URL to a txt file." name="description"/><meta content="Free Web Scraping Tool - Nanonets Online Web Scraper" property="og:title"/><meta content="Free web scraping tool to convert HTML to text. Use Nanonets' web scraper with Python API integration to instantly convert any website URL to a txt file." property="og:description"/><meta content="Free Web Scraping Tool - Nanonets Online Web Scraper" property="twitter:title"/><meta co
# ...

# %%
soup.body
# Out:
# <body><div class="nav page-root-new new w-nav" data-animation="default" data-collapse="medium" data-duration="400" data-easing="ease" data-easing2="ease" role="banner"><div><header class="how-it-works head v3 w-container"><div class="nav-wrap new"><div class="navbar-block v3"><a class="nav__logo w-nav-brand" href="https://nanonets.com/"><img alt="nanonets logo" class="image-127" height="30" loading="lazy" src="https://cdn.prod.website-files.com/602f5458a0b1d868c6c84d5b/60307e489ca8621554af197d_logo2.webp" width="123"/></a><nav class="nav__menu-new v3 w-nav-menu" role="navigation"><div class="nav-menu-left v3"><div class="nav-v3-link v3 w-dropdown" data-delay="0" data-hover="true"><div class="nav__link-wrapper v3 w-dropdown-toggle"><div>Platform</div><div class="dropdown_line"></div><img alt="" class="dropdown-nav-icon" loading="lazy" src="https://cdn.prod.website-files.com/602f5458a0b1d868c6c84d5b/641c17ecc240b1fada3331a6_arrow.svg"/></div><nav class="nav__dropdown-block w-dropdown-l
# ...

# %%
soup.find("h1")
# Out:
# <h1 class="heading-34">Free Web Scraping Tool - Convert Website to Text</h1>

# %%
soup.find_all("h1")
# Out:
# [<h1 class="heading-34">Free Web Scraping Tool - Convert Website to Text</h1>,
#  <h1 class="nn_titles h2 small tools">Suggested Resources</h1>]

# %%
soup.find_all("p")
# Out:
# [<p class="paragraph-34">Data security comes first – We'll never sell or share your data. For more details, here’s our <a class="link-6" href="https://legal.nanonets.com/privacy" target="_blank">Privacy Policy</a></p>,
#  <p class="paragraph-54">Enter any URL which you want to parse</p>,
#  <p class="paragraph-54">Our web scraping tool will render the webpage, perform OCR on it, and extract webpage text.</p>,
#  <p class="paragraph-54">Download your webpage text file within seconds.</p>,
#  <p class="paragraph-4 _400 _42 ghj">Building Smarter: ACM Services <strong>saves 90% time for its Accounts Payable Team</strong> with Nanonets Invoice Extraction</p>,
#  <p class="paragraph-4 _400 _42 ghj">Passport to success: Expatrio achieves <strong>95% reduction in time</strong> <strong>for Manual Data Entry </strong>with Nanonets OCR</p>,
#  <p class="paragraph-4 _400 _42 ghj">In2 Project Management <strong>helps Water Supply Corporation save 700,000 AUD</strong> with Nanonets AI</p>,
# ...

# %% [markdown]
# # **COMMENTS**

# %%
com = soup.p.string
com

# %%
soup.p.prettify()
# Out:
# '<p class="paragraph-34">\n Data security comes first – We\'ll never sell or share your data. For more details, here’s our\n <a class="link-6" href="https://legal.nanonets.com/privacy" target="_blank">\n  Privacy Policy\n </a>\n</p>\n'
